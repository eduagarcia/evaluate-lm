# %%
import os
import json
import pandas as pd
import glob
import yaml

# %%
def open_data_file(filepath):
    data = None
    with open(filepath, 'r') as f:
        if filepath.endswith('.json'):
            data = json.load(f)
        else:
            data = yaml.safe_load(f)
    return data

def load_data_dict_from_folder(finetuning_dir):
    data = {}
    results_path = os.path.join(finetuning_dir, 'all_results.json')
    hparams_path = os.path.join(finetuning_dir, 'config.yaml')
    if not os.path.exists(results_path) or not os.path.exists(hparams_path):
        return
    config = open_data_file(hparams_path)
    data['model_name_or_path'] = config['model_name_or_path']
    data['task_name'] = config['dataset_config_name']
    data['hparam_learning_rate'] = config['learning_rate']
    data['hparam_batch_size'] = config['per_device_train_batch_size']
    results = open_data_file(results_path)
    data['f1'] = results['predict_f1']
    data['eval_f1'] = results['eval_f1']
    return data

# %%
DATA_PATH = "/workspace/models/evaluate_lm_tese"
study_names_to_include = [
    "ju_ner_focus_v1_2",
    "ju_ner_focus_v1_1",
    "ju_cls_focus_v1",
    "cnj_cls_focus_v1",
    "cnj_ner_focus_v1",
    "cnj_ner_focus_v1_retry",
    #"ju_ner_focus_v2",
    #"ju_cls_focus_v2",
    #"cnj_cls_focus_v2",
    #"cnj_ner_focus_v2",
]

# %%
all_res = []
for study in study_names_to_include:
    study_dir = os.path.join(DATA_PATH, study)
    if not os.path.exists(study_dir):
        print(f'{study_dir} not exists')
        continue
    trials_list = [d for d in os.listdir(os.path.join(DATA_PATH, study)) if 'trial_' in d]
    for trial_id in trials_list:
        res = load_data_dict_from_folder(os.path.join(study_dir, trial_id))
        if res:
            res['trial_id'] = trial_id
            all_res.append(res)
df_res = pd.DataFrame(all_res)
# Out:
# /workspace/models/evaluate_lm_tese/ju_ner_focus_v1_2 not exists
# /workspace/models/evaluate_lm_tese/ju_ner_focus_v1_1 not exists
# /workspace/models/evaluate_lm_tese/ju_cls_focus_v1 not exists
# /workspace/models/evaluate_lm_tese/cnj_cls_focus_v1 not exists

# %%
df_res.groupby('model_name_or_path')['f1'].count()
# Out:
# model_name_or_path
# eduagarcia-temp/brwac_large_v1_2__checkpoint_last    19
# eduagarcia-temp/brwac_v1_2__checkpoint_last           9
# eduagarcia-temp/cnj_v1_2__checkpoint_last            16
# eduagarcia/r_j_v2_checkpoint_12000                   24
# neuralmind/bert-base-portuguese-cased                20
# neuralmind/bert-large-portuguese-cased               12
# projetocnj/roberta-base-juridico-v0.3                12
# Name: f1, dtype: int64

# %%
df_res.groupby('task_name')['f1'].count()
# Out:
# task_name
# ceia-entidades    39
# datalawyer-ner    37
# fgv-coarse        36
# Name: f1, dtype: int64

# %%
df_res.groupby(['task_name'])['eval_f1'].describe().sort_values('std', ascending=False)
# Out:
#                 count      mean       std       min       25%       50%  \
# task_name
# ceia-entidades   39.0  0.793723  0.132911  0.000000  0.807405  0.820154
# fgv-coarse       36.0  0.752656  0.017668  0.718442  0.743242  0.749269
# datalawyer-ner   37.0  0.852961  0.017503  0.820538  0.839107  0.849091
#
#                      75%       max
# task_name
# ceia-entidades  0.826939  0.839958
# fgv-coarse      0.760164  0.792774
# datalawyer-ner  0.865484  0.885525

# %%
df_res.groupby('model_name_or_path')['eval_f1'].mean().sort_values(ascending=False)
# Out:
# model_name_or_path
# projetocnj/roberta-base-juridico-v0.3                0.821713
# eduagarcia-temp/brwac_v1_2__checkpoint_last          0.814273
# eduagarcia-temp/brwac_large_v1_2__checkpoint_last    0.807846
# eduagarcia/r_j_v2_checkpoint_12000                   0.807450
# neuralmind/bert-base-portuguese-cased                0.798372
# eduagarcia-temp/cnj_v1_2__checkpoint_last            0.795539
# neuralmind/bert-large-portuguese-cased               0.749782
# Name: eval_f1, dtype: float64

# %%
df_res.groupby('model_name_or_path')['f1'].mean().sort_values(ascending=False)
# Out:
# model_name_or_path
# projetocnj/roberta-base-juridico-v0.3                0.828656
# eduagarcia/r_j_v2_checkpoint_12000                   0.820942
# eduagarcia-temp/cnj_v1_2__checkpoint_last            0.817351
# eduagarcia-temp/brwac_v1_2__checkpoint_last          0.816599
# neuralmind/bert-base-portuguese-cased                0.813946
# eduagarcia-temp/brwac_large_v1_2__checkpoint_last    0.811740
# neuralmind/bert-large-portuguese-cased               0.758358
# Name: f1, dtype: float64

# %%
pd.set_option('display.max_rows', 200)
df_res.groupby(['task_name', 'model_name_or_path']).max()[['f1']].sort_values(['task_name', 'f1'], ascending=False).head
# Out:
# <bound method NDFrame.head of                                                                         f1
# task_name      model_name_or_path
# fgv-coarse     eduagarcia/r_j_v2_checkpoint_12000                 0.808250
#                eduagarcia-temp/brwac_large_v1_2__checkpoint_last  0.808061
#                projetocnj/roberta-base-juridico-v0.3              0.806596
#                neuralmind/bert-large-portuguese-cased             0.806237
#                eduagarcia-temp/cnj_v1_2__checkpoint_last          0.802121
#                neuralmind/bert-base-portuguese-cased              0.795889
#                eduagarcia-temp/brwac_v1_2__checkpoint_last        0.787975
# datalawyer-ner neuralmind/bert-base-portuguese-cased              0.885339
#                projetocnj/roberta-base-juridico-v0.3              0.878879
#                neuralmind/bert-large-portuguese-cased             0.877336
#                eduagarcia-temp/cnj_v1_2__checkpoint_last          0.869826
#                eduagarcia-temp/brwac_large_v1_2__checkpoint_last  0.862939
#                eduagarcia/r_j_v2_checkpoint_12000                 0.857547
#                eduagarcia-temp/brwac_v1_2__checkpoint_last        0.852735
# ceia-entidades eduagarcia-temp/cnj_v1_2__checkpoint_last          0.832060
#                eduagarcia/r_j_v2_checkpoint_12000                 0.831699
#                projetocnj/roberta-base-juridico-v0.3              0.828011
#                neuralmind/bert-large-portuguese-cased             0.826831
#                eduagarcia-temp/brwac_large_v1_2__checkpoint_last  0.826791
#                neuralmind/bert-base-portuguese-cased              0.822857
#                eduagarcia-temp/brwac_v1_2__checkpoint_last        0.802305>

# %%
task_to_consider = [
    'datalawyer-frases',
    'LeNER-Br',
    'ceia-frases',
    'rrip',
    'UlyssesNER-Br-PL-fine',
    'UlyssesNER-Br-PL-coarse',
    'UlyssesNER-Br-C-coarse',
    'UlyssesNER-Br-C-fine',
    'mapa_pt_coarse',
    'mapa_pt_fine'
]
filter_tasks_df = df_res[df_res['task_name'].isin(task_to_consider)]

# %%
filter_tasks_df.groupby('model_name_or_path')['eval_f1'].mean().sort_values(ascending=False)
# Out:
# model_name_or_path
# eduagarcia-temp/brwac_large_v1_2__checkpoint_last    0.842606
# neuralmind/bert-large-portuguese-cased               0.842200
# eduagarcia-temp/brwac_v1_2__checkpoint_last          0.830269
# neuralmind/bert-base-portuguese-cased                0.823985
# eduagarcia/r_j_v2_checkpoint_12000                   0.821876
# eduagarcia-temp/cnj_v1_2__checkpoint_last            0.815678
# projetocnj/roberta-base-juridico-v0.3                0.813277
# Name: eval_f1, dtype: float64

# %%
filter_tasks_df.groupby(['task_name', 'model_name_or_path']).mean()[['f1']].sort_values(['task_name', 'f1'], ascending=False)
# Out:
#                                                                                  f1
# task_name               model_name_or_path
# rrip                    eduagarcia/r_j_v2_checkpoint_12000                 0.834518
#                         projetocnj/roberta-base-juridico-v0.3              0.832160
#                         neuralmind/bert-large-portuguese-cased             0.831162
#                         eduagarcia-temp/cnj_v1_2__checkpoint_last          0.825999
#                         neuralmind/bert-base-portuguese-cased              0.820164
#                         eduagarcia-temp/brwac_large_v1_2__checkpoint_last  0.815074
#                         eduagarcia-temp/brwac_v1_2__checkpoint_last        0.802590
# mapa_pt_fine            neuralmind/bert-large-portuguese-cased             0.921605
#                         eduagarcia-temp/brwac_large_v1_2__checkpoint_last  0.918709
#                         neuralmind/bert-base-portuguese-cased              0.914871
#                         eduagarcia-temp/brwac_v1_2__checkpoint_last        0.908359
#                         eduagarcia/r_j_v2_checkpoint_12000                 0.879891
#                         eduagarcia-temp/cnj_v1_2__checkpoint_last          0.807218
#                         projetocnj/roberta-base-juridico-v0.3              0.794002
# mapa_pt_coarse          eduagarcia/r_j_v2_checkpoint_12000                 0.726536
#                         neuralmind/bert-base-portuguese-cased              0.719454
#                         neuralmind/bert-large-portuguese-cased             0.716811
#                         eduagarcia-temp/brwac_large_v1_2__checkpoint_last  0.693827
#                         eduagarcia-temp/brwac_v1_2__checkpoint_last        0.687060
#                         projetocnj/roberta-base-juridico-v0.3              0.620087
#                         eduagarcia-temp/cnj_v1_2__checkpoint_last          0.579068
# datalawyer-frases       eduagarcia/r_j_v2_checkpoint_12000                 0.847451
#                         projetocnj/roberta-base-juridico-v0.3              0.839038
#                         eduagarcia-temp/cnj_v1_2__checkpoint_last          0.836960
#                         neuralmind/bert-large-portuguese-cased             0.833521
#                         neuralmind/bert-base-portuguese-cased              0.826652
#                         eduagarcia-temp/brwac_large_v1_2__checkpoint_last  0.823218
#                         eduagarcia-temp/brwac_v1_2__checkpoint_last        0.821674
# ceia-frases             eduagarcia/r_j_v2_checkpoint_12000                 0.810398
#                         projetocnj/roberta-base-juridico-v0.3              0.810096
#                         neuralmind/bert-large-portuguese-cased             0.802895
#                         eduagarcia-temp/cnj_v1_2__checkpoint_last          0.799040
#                         neuralmind/bert-base-portuguese-cased              0.794562
#                         eduagarcia-temp/brwac_v1_2__checkpoint_last        0.781661
#                         eduagarcia-temp/brwac_large_v1_2__checkpoint_last  0.779965
# UlyssesNER-Br-PL-fine   eduagarcia-temp/brwac_large_v1_2__checkpoint_last  0.860874
#                         eduagarcia-temp/brwac_v1_2__checkpoint_last        0.853968
#                         neuralmind/bert-large-portuguese-cased             0.845479
#                         neuralmind/bert-base-portuguese-cased              0.829240
#                         eduagarcia/r_j_v2_checkpoint_12000                 0.822670
#                         eduagarcia-temp/cnj_v1_2__checkpoint_last          0.815588
#                         projetocnj/roberta-base-juridico-v0.3              0.815223
# UlyssesNER-Br-PL-coarse eduagarcia-temp/brwac_large_v1_2__checkpoint_last  0.875523
#                         eduagarcia-temp/brwac_v1_2__checkpoint_last        0.874102
#                         neuralmind/bert-large-portuguese-cased             0.869171
#                         eduagarcia/r_j_v2_checkpoint_12000                 0.856879
#                         neuralmind/bert-base-portuguese-cased              0.844355
#                         eduagarcia-temp/cnj_v1_2__checkpoint_last          0.838253
#                         projetocnj/roberta-base-juridico-v0.3              0.827819
# UlyssesNER-Br-C-fine    eduagarcia-temp/brwac_large_v1_2__checkpoint_last  0.744102
#                         neuralmind/bert-large-portuguese-cased             0.724375
#                         eduagarcia/r_j_v2_checkpoint_12000                 0.706891
#                         eduagarcia-temp/brwac_v1_2__checkpoint_last        0.698931
#                         eduagarcia-temp/cnj_v1_2__checkpoint_last          0.688074
#                         neuralmind/bert-base-portuguese-cased              0.679441
#                         projetocnj/roberta-base-juridico-v0.3              0.620519
# UlyssesNER-Br-C-coarse  eduagarcia-temp/brwac_large_v1_2__checkpoint_last  0.764453
#                         neuralmind/bert-base-portuguese-cased              0.727399
#                         eduagarcia-temp/brwac_v1_2__checkpoint_last        0.726899
#                         eduagarcia/r_j_v2_checkpoint_12000                 0.726713
#                         neuralmind/bert-large-portuguese-cased             0.726610
#                         eduagarcia-temp/cnj_v1_2__checkpoint_last          0.693788
#                         projetocnj/roberta-base-juridico-v0.3              0.679887
# LeNER-Br                projetocnj/roberta-base-juridico-v0.3              0.906437
#                         eduagarcia/r_j_v2_checkpoint_12000                 0.904014
#                         eduagarcia-temp/cnj_v1_2__checkpoint_last          0.887937
#                         eduagarcia-temp/brwac_v1_2__checkpoint_last        0.884813
#                         neuralmind/bert-large-portuguese-cased             0.879956
#                         eduagarcia-temp/brwac_large_v1_2__checkpoint_last  0.877014
#                         neuralmind/bert-base-portuguese-cased              0.874642

# %%
filter_tasks_df.groupby(['task_name', 'model_name_or_path']).max()[['f1']].sort_values(['task_name', 'f1'], ascending=False)
# Out:
#                                                                                  f1
# task_name               model_name_or_path
# rrip                    eduagarcia/r_j_v2_checkpoint_12000                 0.848454
#                         neuralmind/bert-large-portuguese-cased             0.845761
#                         projetocnj/roberta-base-juridico-v0.3              0.844371
#                         eduagarcia-temp/cnj_v1_2__checkpoint_last          0.835208
#                         neuralmind/bert-base-portuguese-cased              0.829627
#                         eduagarcia-temp/brwac_large_v1_2__checkpoint_last  0.826734
#                         eduagarcia-temp/brwac_v1_2__checkpoint_last        0.821618
# mapa_pt_fine            eduagarcia-temp/brwac_v1_2__checkpoint_last        0.935897
#                         neuralmind/bert-base-portuguese-cased              0.935567
#                         eduagarcia-temp/brwac_large_v1_2__checkpoint_last  0.934866
#                         neuralmind/bert-large-portuguese-cased             0.930591
#                         eduagarcia/r_j_v2_checkpoint_12000                 0.898113
#                         projetocnj/roberta-base-juridico-v0.3              0.841572
#                         eduagarcia-temp/cnj_v1_2__checkpoint_last          0.836810
# mapa_pt_coarse          eduagarcia/r_j_v2_checkpoint_12000                 0.768362
#                         neuralmind/bert-large-portuguese-cased             0.742532
#                         eduagarcia-temp/brwac_large_v1_2__checkpoint_last  0.741641
#                         neuralmind/bert-base-portuguese-cased              0.731241
#                         eduagarcia-temp/brwac_v1_2__checkpoint_last        0.729378
#                         projetocnj/roberta-base-juridico-v0.3              0.673443
#                         eduagarcia-temp/cnj_v1_2__checkpoint_last          0.621359
# datalawyer-frases       eduagarcia/r_j_v2_checkpoint_12000                 0.854529
#                         projetocnj/roberta-base-juridico-v0.3              0.853102
#                         eduagarcia-temp/cnj_v1_2__checkpoint_last          0.849182
#                         neuralmind/bert-large-portuguese-cased             0.839797
#                         eduagarcia-temp/brwac_v1_2__checkpoint_last        0.837164
#                         eduagarcia-temp/brwac_large_v1_2__checkpoint_last  0.836115
#                         neuralmind/bert-base-portuguese-cased              0.834116
# ceia-frases             eduagarcia/r_j_v2_checkpoint_12000                 0.820228
#                         eduagarcia-temp/cnj_v1_2__checkpoint_last          0.819650
#                         projetocnj/roberta-base-juridico-v0.3              0.819004
#                         neuralmind/bert-large-portuguese-cased             0.812713
#                         neuralmind/bert-base-portuguese-cased              0.805321
#                         eduagarcia-temp/brwac_large_v1_2__checkpoint_last  0.799625
#                         eduagarcia-temp/brwac_v1_2__checkpoint_last        0.791470
# UlyssesNER-Br-PL-fine   eduagarcia-temp/brwac_large_v1_2__checkpoint_last  0.886914
#                         eduagarcia-temp/brwac_v1_2__checkpoint_last        0.873786
#                         neuralmind/bert-large-portuguese-cased             0.855777
#                         eduagarcia/r_j_v2_checkpoint_12000                 0.854618
#                         eduagarcia-temp/cnj_v1_2__checkpoint_last          0.848875
#                         projetocnj/roberta-base-juridico-v0.3              0.843354
#                         neuralmind/bert-base-portuguese-cased              0.838608
# UlyssesNER-Br-PL-coarse eduagarcia-temp/brwac_large_v1_2__checkpoint_last  0.906122
#                         eduagarcia-temp/brwac_v1_2__checkpoint_last        0.898387
#                         neuralmind/bert-large-portuguese-cased             0.888000
#                         eduagarcia/r_j_v2_checkpoint_12000                 0.880328
#                         neuralmind/bert-base-portuguese-cased              0.872990
#                         eduagarcia-temp/cnj_v1_2__checkpoint_last          0.861711
#                         projetocnj/roberta-base-juridico-v0.3              0.841767
# UlyssesNER-Br-C-fine    eduagarcia-temp/brwac_large_v1_2__checkpoint_last  0.788177
#                         neuralmind/bert-large-portuguese-cased             0.783871
#                         eduagarcia-temp/brwac_v1_2__checkpoint_last        0.755408
#                         eduagarcia/r_j_v2_checkpoint_12000                 0.737864
#                         neuralmind/bert-base-portuguese-cased              0.727273
#                         projetocnj/roberta-base-juridico-v0.3              0.726984
#                         eduagarcia-temp/cnj_v1_2__checkpoint_last          0.718802
# UlyssesNER-Br-C-coarse  eduagarcia-temp/brwac_large_v1_2__checkpoint_last  0.791391
#                         neuralmind/bert-large-portuguese-cased             0.777236
#                         neuralmind/bert-base-portuguese-cased              0.767442
#                         eduagarcia-temp/brwac_v1_2__checkpoint_last        0.760000
#                         projetocnj/roberta-base-juridico-v0.3              0.754839
#                         eduagarcia/r_j_v2_checkpoint_12000                 0.750809
#                         eduagarcia-temp/cnj_v1_2__checkpoint_last          0.732203
# LeNER-Br                projetocnj/roberta-base-juridico-v0.3              0.914177
#                         eduagarcia/r_j_v2_checkpoint_12000                 0.910016
#                         eduagarcia-temp/cnj_v1_2__checkpoint_last          0.905841
#                         eduagarcia-temp/brwac_large_v1_2__checkpoint_last  0.905709
#                         eduagarcia-temp/brwac_v1_2__checkpoint_last        0.894989
#                         neuralmind/bert-large-portuguese-cased             0.892663
#                         neuralmind/bert-base-portuguese-cased              0.884358

# %%
filter_tasks_df.sort_values(['eval_f1'], ascending=False).groupby(['model_name_or_path', 'task_name']).head(1)
# Out:
#                                     model_name_or_path  \
# 294             neuralmind/bert-large-portuguese-cased
# 363        eduagarcia-temp/brwac_v1_2__checkpoint_last
# 199              neuralmind/bert-base-portuguese-cased
# 240  eduagarcia-temp/brwac_large_v1_2__checkpoint_last
# 198                 eduagarcia/r_j_v2_checkpoint_12000
# 312              projetocnj/roberta-base-juridico-v0.3
# 243          eduagarcia-temp/cnj_v1_2__checkpoint_last
# 21   eduagarcia-temp/brwac_large_v1_2__checkpoint_last
# 88               projetocnj/roberta-base-juridico-v0.3
# 98   eduagarcia-temp/brwac_large_v1_2__checkpoint_last
# 96         eduagarcia-temp/brwac_v1_2__checkpoint_last
# 161                 eduagarcia/r_j_v2_checkpoint_12000
# 11         eduagarcia-temp/brwac_v1_2__checkpoint_last
# 52               neuralmind/bert-base-portuguese-cased
# 117  eduagarcia-temp/brwac_large_v1_2__checkpoint_last
# 136              neuralmind/bert-base-portuguese-cased
# 109          eduagarcia-temp/cnj_v1_2__checkpoint_last
# 104             neuralmind/bert-large-portuguese-cased
# 147          eduagarcia-temp/cnj_v1_2__checkpoint_last
# 66              neuralmind/bert-large-portuguese-cased
# 48              neuralmind/bert-large-portuguese-cased
# 5          eduagarcia-temp/brwac_v1_2__checkpoint_last
# 299             neuralmind/bert-large-portuguese-cased
# 31                  eduagarcia/r_j_v2_checkpoint_12000
# 101          eduagarcia-temp/cnj_v1_2__checkpoint_last
# 53               projetocnj/roberta-base-juridico-v0.3
# 8                   eduagarcia/r_j_v2_checkpoint_12000
# 73               neuralmind/bert-base-portuguese-cased
# 640              projetocnj/roberta-base-juridico-v0.3
# 3                projetocnj/roberta-base-juridico-v0.3
# 220              neuralmind/bert-base-portuguese-cased
# 581                 eduagarcia/r_j_v2_checkpoint_12000
# 540          eduagarcia-temp/cnj_v1_2__checkpoint_last
# 580             neuralmind/bert-large-portuguese-cased
# 296        eduagarcia-temp/brwac_v1_2__checkpoint_last
# 662  eduagarcia-temp/brwac_large_v1_2__checkpoint_last
# 610              projetocnj/roberta-base-juridico-v0.3
# 539              neuralmind/bert-base-portuguese-cased
# 598                 eduagarcia/r_j_v2_checkpoint_12000
# 563             neuralmind/bert-large-portuguese-cased
# 250  eduagarcia-temp/brwac_large_v1_2__checkpoint_last
# 573        eduagarcia-temp/brwac_v1_2__checkpoint_last
# 651          eduagarcia-temp/cnj_v1_2__checkpoint_last
# 579  eduagarcia-temp/brwac_large_v1_2__checkpoint_last
# 528                 eduagarcia/r_j_v2_checkpoint_12000
# 282  eduagarcia-temp/brwac_large_v1_2__checkpoint_last
# 526              projetocnj/roberta-base-juridico-v0.3
# 518          eduagarcia-temp/cnj_v1_2__checkpoint_last
# 531              neuralmind/bert-base-portuguese-cased
# 209             neuralmind/bert-large-portuguese-cased
# 577        eduagarcia-temp/brwac_v1_2__checkpoint_last
# 590  eduagarcia-temp/brwac_large_v1_2__checkpoint_last
# 605             neuralmind/bert-large-portuguese-cased
# 272              projetocnj/roberta-base-juridico-v0.3
# 617              neuralmind/bert-base-portuguese-cased
# 259          eduagarcia-temp/cnj_v1_2__checkpoint_last
# 202        eduagarcia-temp/brwac_v1_2__checkpoint_last
# 391              neuralmind/bert-base-portuguese-cased
# 609        eduagarcia-temp/brwac_v1_2__checkpoint_last
# 211  eduagarcia-temp/brwac_large_v1_2__checkpoint_last
# 213             neuralmind/bert-large-portuguese-cased
# 378                 eduagarcia/r_j_v2_checkpoint_12000
# 359                 eduagarcia/r_j_v2_checkpoint_12000
# 293              projetocnj/roberta-base-juridico-v0.3
# 366        eduagarcia-temp/brwac_v1_2__checkpoint_last
# 334          eduagarcia-temp/cnj_v1_2__checkpoint_last
# 361              neuralmind/bert-base-portuguese-cased
# 238                 eduagarcia/r_j_v2_checkpoint_12000
# 262              projetocnj/roberta-base-juridico-v0.3
# 291          eduagarcia-temp/cnj_v1_2__checkpoint_last
#
#                    task_name  hparam_learning_rate  hparam_batch_size  \
# 294             mapa_pt_fine              0.000025                 16
# 363             mapa_pt_fine              0.000025                 32
# 199             mapa_pt_fine              0.000050                 16
# 240             mapa_pt_fine              0.000050                 16
# 198             mapa_pt_fine              0.000025                 16
# 312             mapa_pt_fine              0.000025                 16
# 243             mapa_pt_fine              0.000010                 16
# 21   UlyssesNER-Br-PL-coarse              0.000025                 32
# 88                  LeNER-Br              0.000050                 16
# 98     UlyssesNER-Br-PL-fine              0.000025                 16
# 96     UlyssesNER-Br-PL-fine              0.000025                 16
# 161                 LeNER-Br              0.000010                 16
# 11   UlyssesNER-Br-PL-coarse              0.000050                 32
# 52   UlyssesNER-Br-PL-coarse              0.000050                 16
# 117                 LeNER-Br              0.000010                 16
# 136    UlyssesNER-Br-PL-fine              0.000050                 16
# 109  UlyssesNER-Br-PL-coarse              0.000050                 32
# 104  UlyssesNER-Br-PL-coarse              0.000025                 16
# 147                 LeNER-Br              0.000025                 32
# 66                  LeNER-Br              0.000050                 32
# 48     UlyssesNER-Br-PL-fine              0.000050                 16
# 5                   LeNER-Br              0.000010                 16
# 299           mapa_pt_coarse              0.000025                 32
# 31     UlyssesNER-Br-PL-fine              0.000050                 16
# 101    UlyssesNER-Br-PL-fine              0.000050                 32
# 53     UlyssesNER-Br-PL-fine              0.000050                 32
# 8    UlyssesNER-Br-PL-coarse              0.000050                 32
# 73                  LeNER-Br              0.000050                 16
# 640        datalawyer-frases              0.000008                 16
# 3    UlyssesNER-Br-PL-coarse              0.000050                 32
# 220           mapa_pt_coarse              0.000050                 16
# 581        datalawyer-frases              0.000025                 32
# 540        datalawyer-frases              0.000008                 32
# 580        datalawyer-frases              0.000010                 16
# 296           mapa_pt_coarse              0.000050                 32
# 662        datalawyer-frases              0.000010                 16
# 610                     rrip              0.000008                 16
# 539        datalawyer-frases              0.000008                 16
# 598                     rrip              0.000008                 16
# 563                     rrip              0.000050                 16
# 250   UlyssesNER-Br-C-coarse              0.000025                 32
# 573        datalawyer-frases              0.000008                 16
# 651                     rrip              0.000010                 16
# 579                     rrip              0.000010                 16
# 528              ceia-frases              0.000008                 32
# 282     UlyssesNER-Br-C-fine              0.000025                 32
# 526              ceia-frases              0.000010                 32
# 518              ceia-frases              0.000008                 32
# 531                     rrip              0.000050                 32
# 209   UlyssesNER-Br-C-coarse              0.000050                 16
# 577                     rrip              0.000010                 32
# 590              ceia-frases              0.000008                 32
# 605              ceia-frases              0.000010                 32
# 272           mapa_pt_coarse              0.000025                 16
# 617              ceia-frases              0.000050                 32
# 259           mapa_pt_coarse              0.000050                 16
# 202   UlyssesNER-Br-C-coarse              0.000050                 16
# 391   UlyssesNER-Br-C-coarse              0.000025                 16
# 609              ceia-frases              0.000025                 32
# 211           mapa_pt_coarse              0.000050                 32
# 213     UlyssesNER-Br-C-fine              0.000050                 16
# 378           mapa_pt_coarse              0.000050                 16
# 359   UlyssesNER-Br-C-coarse              0.000025                 16
# 293   UlyssesNER-Br-C-coarse              0.000050                 16
# 366     UlyssesNER-Br-C-fine              0.000025                 16
# 334   UlyssesNER-Br-C-coarse              0.000025                 32
# 361     UlyssesNER-Br-C-fine              0.000050                 32
# 238     UlyssesNER-Br-C-fine              0.000025                 16
# 262     UlyssesNER-Br-C-fine              0.000050                 16
# 291     UlyssesNER-Br-C-fine              0.000050                 16
#
#            f1   eval_f1
# 294  0.925786  0.968661
# 363  0.923469  0.966480
# 199  0.911652  0.965909
# 240  0.891534  0.962751
# 198  0.896465  0.930748
# 312  0.802938  0.930636
# 243  0.791027  0.913165
# 21   0.894231  0.906115
# 88   0.911755  0.902003
# 98   0.886914  0.900777
# 96   0.873786  0.898625
# 161  0.903369  0.898504
# 11   0.898387  0.895319
# 52   0.870607  0.893471
# 117  0.885687  0.892722
# 136  0.838155  0.889080
# 109  0.858293  0.883162
# 104  0.888000  0.882653
# 147  0.893766  0.881680
# 66   0.891728  0.879553
# 48   0.855777  0.877882
# 5    0.894989  0.875067
# 299  0.725714  0.872549
# 31   0.852327  0.872232
# 101  0.825321  0.867347
# 53   0.833465  0.866155
# 8    0.873693  0.865801
# 73   0.884358  0.862490
# 640  0.843009  0.862252
# 3    0.837136  0.861252
# 220  0.717877  0.859903
# 581  0.853870  0.857281
# 540  0.841673  0.855365
# 580  0.837270  0.853012
# 296  0.729378  0.851675
# 662  0.836115  0.846409
# 610  0.805841  0.846131
# 539  0.826591  0.845601
# 598  0.834736  0.844869
# 563  0.845761  0.842377
# 250  0.768982  0.841924
# 573  0.824669  0.840309
# 651  0.827563  0.840285
# 579  0.818953  0.837104
# 528  0.815368  0.831018
# 282  0.767480  0.830508
# 526  0.819004  0.828567
# 518  0.819650  0.824076
# 531  0.823475  0.823488
# 209  0.777236  0.820870
# 577  0.821618  0.819994
# 590  0.799625  0.816557
# 605  0.812713  0.815628
# 272  0.627249  0.815534
# 617  0.796101  0.804273
# 259  0.536842  0.803828
# 202  0.732639  0.803540
# 391  0.756137  0.800681
# 609  0.781066  0.799744
# 211  0.718894  0.796209
# 213  0.771704  0.791171
# 378  0.671214  0.787037
# 359  0.750809  0.783051
# 293  0.754839  0.776632
# 366  0.755408  0.761905
# 334  0.698675  0.759227
# 361  0.727273  0.758853
# 238  0.737864  0.758389
# 262  0.726984  0.738095
# 291  0.718802  0.736111

# %%
best_hparams_df = filter_tasks_df.sort_values('eval_f1', ascending=False).groupby(['model_name_or_path', 'task_name']).head(3).groupby(['model_name_or_path', 'task_name'])[['f1', 'eval_f1']].mean().reset_index()
best_hparams_df.sort_values('f1', ascending=False)
# Out:
#                                    model_name_or_path  \
# 48              neuralmind/bert-base-portuguese-cased
# 58             neuralmind/bert-large-portuguese-cased
# 18        eduagarcia-temp/brwac_v1_2__checkpoint_last
# 8   eduagarcia-temp/brwac_large_v1_2__checkpoint_last
# 60              projetocnj/roberta-base-juridico-v0.3
# 30                 eduagarcia/r_j_v2_checkpoint_12000
# 20          eduagarcia-temp/cnj_v1_2__checkpoint_last
# 38                 eduagarcia/r_j_v2_checkpoint_12000
# 3   eduagarcia-temp/brwac_large_v1_2__checkpoint_last
# 0   eduagarcia-temp/brwac_large_v1_2__checkpoint_last
# 10        eduagarcia-temp/brwac_v1_2__checkpoint_last
# 50             neuralmind/bert-large-portuguese-cased
# 13        eduagarcia-temp/brwac_v1_2__checkpoint_last
# 40              neuralmind/bert-base-portuguese-cased
# 53             neuralmind/bert-large-portuguese-cased
# 33                 eduagarcia/r_j_v2_checkpoint_12000
# 14        eduagarcia-temp/brwac_v1_2__checkpoint_last
# 4   eduagarcia-temp/brwac_large_v1_2__checkpoint_last
# 43              neuralmind/bert-base-portuguese-cased
# 23          eduagarcia-temp/cnj_v1_2__checkpoint_last
# 36                 eduagarcia/r_j_v2_checkpoint_12000
# 54             neuralmind/bert-large-portuguese-cased
# 66              projetocnj/roberta-base-juridico-v0.3
# 34                 eduagarcia/r_j_v2_checkpoint_12000
# 26          eduagarcia-temp/cnj_v1_2__checkpoint_last
# 63              projetocnj/roberta-base-juridico-v0.3
# 39                 eduagarcia/r_j_v2_checkpoint_12000
# 64              projetocnj/roberta-base-juridico-v0.3
# 44              neuralmind/bert-base-portuguese-cased
# 59             neuralmind/bert-large-portuguese-cased
# 56             neuralmind/bert-large-portuguese-cased
# 24          eduagarcia-temp/cnj_v1_2__checkpoint_last
# 46              neuralmind/bert-base-portuguese-cased
# 29          eduagarcia-temp/cnj_v1_2__checkpoint_last
# 16        eduagarcia-temp/brwac_v1_2__checkpoint_last
# 6   eduagarcia-temp/brwac_large_v1_2__checkpoint_last
# 69              projetocnj/roberta-base-juridico-v0.3
# 9   eduagarcia-temp/brwac_large_v1_2__checkpoint_last
# 49              neuralmind/bert-base-portuguese-cased
# 68              projetocnj/roberta-base-juridico-v0.3
# 28          eduagarcia-temp/cnj_v1_2__checkpoint_last
# 65              projetocnj/roberta-base-juridico-v0.3
# 35                 eduagarcia/r_j_v2_checkpoint_12000
# 25          eduagarcia-temp/cnj_v1_2__checkpoint_last
# 55             neuralmind/bert-large-portuguese-cased
# 19        eduagarcia-temp/brwac_v1_2__checkpoint_last
# 5   eduagarcia-temp/brwac_large_v1_2__checkpoint_last
# 45              neuralmind/bert-base-portuguese-cased
# 15        eduagarcia-temp/brwac_v1_2__checkpoint_last
# 1   eduagarcia-temp/brwac_large_v1_2__checkpoint_last
# 2   eduagarcia-temp/brwac_large_v1_2__checkpoint_last
# 52             neuralmind/bert-large-portuguese-cased
# 41              neuralmind/bert-base-portuguese-cased
# 51             neuralmind/bert-large-portuguese-cased
# 31                 eduagarcia/r_j_v2_checkpoint_12000
# 32                 eduagarcia/r_j_v2_checkpoint_12000
# 11        eduagarcia-temp/brwac_v1_2__checkpoint_last
# 7   eduagarcia-temp/brwac_large_v1_2__checkpoint_last
# 61              projetocnj/roberta-base-juridico-v0.3
# 42              neuralmind/bert-base-portuguese-cased
# 47              neuralmind/bert-base-portuguese-cased
# 12        eduagarcia-temp/brwac_v1_2__checkpoint_last
# 37                 eduagarcia/r_j_v2_checkpoint_12000
# 22          eduagarcia-temp/cnj_v1_2__checkpoint_last
# 57             neuralmind/bert-large-portuguese-cased
# 17        eduagarcia-temp/brwac_v1_2__checkpoint_last
# 62              projetocnj/roberta-base-juridico-v0.3
# 21          eduagarcia-temp/cnj_v1_2__checkpoint_last
# 67              projetocnj/roberta-base-juridico-v0.3
# 27          eduagarcia-temp/cnj_v1_2__checkpoint_last
#
#                   task_name        f1   eval_f1
# 48             mapa_pt_fine  0.925356  0.962962
# 58             mapa_pt_fine  0.923265  0.961970
# 18             mapa_pt_fine  0.921088  0.963803
# 8              mapa_pt_fine  0.914395  0.960550
# 60                 LeNER-Br  0.912964  0.894165
# 30                 LeNER-Br  0.906193  0.897018
# 20                 LeNER-Br  0.896819  0.879509
# 38             mapa_pt_fine  0.893530  0.919857
# 3   UlyssesNER-Br-PL-coarse  0.893515  0.901497
# 0                  LeNER-Br  0.892277  0.888999
# 10                 LeNER-Br  0.887307  0.868883
# 50                 LeNER-Br  0.886371  0.872803
# 13  UlyssesNER-Br-PL-coarse  0.884588  0.893570
# 40                 LeNER-Br  0.883363  0.859403
# 53  UlyssesNER-Br-PL-coarse  0.877673  0.880198
# 33  UlyssesNER-Br-PL-coarse  0.870165  0.863735
# 14    UlyssesNER-Br-PL-fine  0.868716  0.896018
# 4     UlyssesNER-Br-PL-fine  0.867607  0.898459
# 43  UlyssesNER-Br-PL-coarse  0.863900  0.891882
# 23  UlyssesNER-Br-PL-coarse  0.850405  0.874788
# 36        datalawyer-frases  0.849139  0.854596
# 54    UlyssesNER-Br-PL-fine  0.847388  0.872611
# 66        datalawyer-frases  0.845930  0.860048
# 34    UlyssesNER-Br-PL-fine  0.844468  0.868077
# 26        datalawyer-frases  0.843930  0.852801
# 63  UlyssesNER-Br-PL-coarse  0.839119  0.855477
# 39                     rrip  0.839072  0.843370
# 64    UlyssesNER-Br-PL-fine  0.838305  0.861350
# 44    UlyssesNER-Br-PL-fine  0.838271  0.883777
# 59                     rrip  0.837894  0.841714
# 56        datalawyer-frases  0.835841  0.851510
# 24    UlyssesNER-Br-PL-fine  0.832238  0.863294
# 46        datalawyer-frases  0.830658  0.843637
# 29                     rrip  0.829711  0.839128
# 16        datalawyer-frases  0.829477  0.836627
# 6         datalawyer-frases  0.828915  0.845172
# 69                     rrip  0.828472  0.843470
# 9                      rrip  0.823567  0.832486
# 49                     rrip  0.823351  0.822484
# 68             mapa_pt_fine  0.821050  0.922842
# 28             mapa_pt_fine  0.819327  0.907364
# 65              ceia-frases  0.817559  0.825326
# 35              ceia-frases  0.816933  0.828681
# 25              ceia-frases  0.813967  0.819394
# 55              ceia-frases  0.810187  0.814574
# 19                     rrip  0.805858  0.819886
# 5               ceia-frases  0.797215  0.811566
# 45              ceia-frases  0.796991  0.801606
# 15              ceia-frases  0.785330  0.798124
# 1    UlyssesNER-Br-C-coarse  0.777800  0.831265
# 2      UlyssesNER-Br-C-fine  0.774630  0.814192
# 52     UlyssesNER-Br-C-fine  0.765159  0.778258
# 41   UlyssesNER-Br-C-coarse  0.759515  0.797880
# 51   UlyssesNER-Br-C-coarse  0.750276  0.809008
# 31   UlyssesNER-Br-C-coarse  0.744604  0.779722
# 32     UlyssesNER-Br-C-fine  0.734465  0.754512
# 11   UlyssesNER-Br-C-coarse  0.732128  0.791702
# 7            mapa_pt_coarse  0.721001  0.784210
# 61   UlyssesNER-Br-C-coarse  0.720830  0.762704
# 42     UlyssesNER-Br-C-fine  0.720454  0.744894
# 47           mapa_pt_coarse  0.719972  0.823095
# 12     UlyssesNER-Br-C-fine  0.719074  0.755626
# 37           mapa_pt_coarse  0.717130  0.757219
# 22     UlyssesNER-Br-C-fine  0.704332  0.727633
# 57           mapa_pt_coarse  0.703342  0.848842
# 17           mapa_pt_coarse  0.698925  0.811284
# 62     UlyssesNER-Br-C-fine  0.695546  0.723710
# 21   UlyssesNER-Br-C-coarse  0.693843  0.755888
# 67           mapa_pt_coarse  0.642177  0.814699
# 27           mapa_pt_coarse  0.554976  0.784609

# %%
best_hparams_df.groupby(['task_name'])['f1'].describe().sort_values('std', ascending=False)
# Out:
#                          count      mean       std       min       25%  \
# task_name
# mapa_pt_coarse             7.0  0.679646  0.061402  0.554976  0.670551
# mapa_pt_fine               7.0  0.888287  0.047713  0.819327  0.857290
# UlyssesNER-Br-C-fine       7.0  0.730523  0.029728  0.695546  0.711703
# UlyssesNER-Br-C-coarse     7.0  0.739857  0.027375  0.693843  0.726479
# UlyssesNER-Br-PL-coarse    7.0  0.868481  0.019076  0.839119  0.857152
# UlyssesNER-Br-PL-fine      7.0  0.848142  0.014511  0.832238  0.838288
# ceia-frases                7.0  0.805455  0.012367  0.785330  0.797103
# rrip                       7.0  0.826846  0.011149  0.805858  0.823459
# LeNER-Br                   7.0  0.895042  0.011013  0.883363  0.886839
# datalawyer-frases          7.0  0.837699  0.008517  0.828915  0.830067
#
#                               50%       75%       max
# task_name
# mapa_pt_coarse           0.703342  0.718551  0.721001
# mapa_pt_fine             0.914395  0.922177  0.925356
# UlyssesNER-Br-C-fine     0.720454  0.749812  0.774630
# UlyssesNER-Br-C-coarse   0.744604  0.754896  0.777800
# UlyssesNER-Br-PL-coarse  0.870165  0.881130  0.893515
# UlyssesNER-Br-PL-fine    0.844468  0.857498  0.868716
# ceia-frases              0.810187  0.815450  0.817559
# rrip                     0.828472  0.833803  0.839072
# LeNER-Br                 0.892277  0.901506  0.912964
# datalawyer-frases        0.835841  0.844930  0.849139

# %%
best_hparams_df.groupby(['model_name_or_path'])['f1'].describe().sort_values('mean', ascending=False)
# Out:
#                                                    count      mean       std  \
# model_name_or_path
# eduagarcia-temp/brwac_large_v1_2__checkpoint_last   10.0  0.829092  0.062566
# neuralmind/bert-large-portuguese-cased              10.0  0.823740  0.067619
# eduagarcia/r_j_v2_checkpoint_12000                  10.0  0.821570  0.067274
# neuralmind/bert-base-portuguese-cased               10.0  0.816183  0.067871
# eduagarcia-temp/brwac_v1_2__checkpoint_last         10.0  0.813249  0.078100
# projetocnj/roberta-base-juridico-v0.3               10.0  0.796195  0.082578
# eduagarcia-temp/cnj_v1_2__checkpoint_last           10.0  0.783955  0.102317
#
#                                                         min       25%  \
# model_name_or_path
# eduagarcia-temp/brwac_large_v1_2__checkpoint_last  0.721001  0.782654
# neuralmind/bert-large-portuguese-cased             0.703342  0.776416
# eduagarcia/r_j_v2_checkpoint_12000                 0.717130  0.762686
# neuralmind/bert-base-portuguese-cased              0.719972  0.768884
# eduagarcia-temp/brwac_v1_2__checkpoint_last        0.698925  0.745429
# projetocnj/roberta-base-juridico-v0.3              0.642177  0.745012
# eduagarcia-temp/cnj_v1_2__checkpoint_last          0.554976  0.731741
#
#                                                         50%       75%  \
# model_name_or_path
# eduagarcia-temp/brwac_large_v1_2__checkpoint_last  0.826241  0.886110
# neuralmind/bert-large-portuguese-cased             0.836868  0.870102
# eduagarcia/r_j_v2_checkpoint_12000                 0.841770  0.864908
# neuralmind/bert-base-portuguese-cased              0.827004  0.857492
# eduagarcia-temp/brwac_v1_2__checkpoint_last        0.817667  0.880620
# projetocnj/roberta-base-juridico-v0.3              0.824761  0.838916
# eduagarcia-temp/cnj_v1_2__checkpoint_last          0.824519  0.841007
#
#                                                         max
# model_name_or_path
# eduagarcia-temp/brwac_large_v1_2__checkpoint_last  0.914395
# neuralmind/bert-large-portuguese-cased             0.923265
# eduagarcia/r_j_v2_checkpoint_12000                 0.906193
# neuralmind/bert-base-portuguese-cased              0.925356
# eduagarcia-temp/brwac_v1_2__checkpoint_last        0.921088
# projetocnj/roberta-base-juridico-v0.3              0.912964
# eduagarcia-temp/cnj_v1_2__checkpoint_last          0.896819

# %%
best_hparams_df[['model_name_or_path', 'task_name', 'f1']].sort_values(['task_name', 'f1'], ascending=False).set_index(['task_name', 'model_name_or_path'])
# Out:
#                                                                                  f1
# task_name               model_name_or_path
# rrip                    eduagarcia/r_j_v2_checkpoint_12000                 0.839072
#                         neuralmind/bert-large-portuguese-cased             0.837894
#                         eduagarcia-temp/cnj_v1_2__checkpoint_last          0.829711
#                         projetocnj/roberta-base-juridico-v0.3              0.828472
#                         eduagarcia-temp/brwac_large_v1_2__checkpoint_last  0.823567
#                         neuralmind/bert-base-portuguese-cased              0.823351
#                         eduagarcia-temp/brwac_v1_2__checkpoint_last        0.805858
# mapa_pt_fine            neuralmind/bert-base-portuguese-cased              0.925356
#                         neuralmind/bert-large-portuguese-cased             0.923265
#                         eduagarcia-temp/brwac_v1_2__checkpoint_last        0.921088
#                         eduagarcia-temp/brwac_large_v1_2__checkpoint_last  0.914395
#                         eduagarcia/r_j_v2_checkpoint_12000                 0.893530
#                         projetocnj/roberta-base-juridico-v0.3              0.821050
#                         eduagarcia-temp/cnj_v1_2__checkpoint_last          0.819327
# mapa_pt_coarse          eduagarcia-temp/brwac_large_v1_2__checkpoint_last  0.721001
#                         neuralmind/bert-base-portuguese-cased              0.719972
#                         eduagarcia/r_j_v2_checkpoint_12000                 0.717130
#                         neuralmind/bert-large-portuguese-cased             0.703342
#                         eduagarcia-temp/brwac_v1_2__checkpoint_last        0.698925
#                         projetocnj/roberta-base-juridico-v0.3              0.642177
#                         eduagarcia-temp/cnj_v1_2__checkpoint_last          0.554976
# datalawyer-frases       eduagarcia/r_j_v2_checkpoint_12000                 0.849139
#                         projetocnj/roberta-base-juridico-v0.3              0.845930
#                         eduagarcia-temp/cnj_v1_2__checkpoint_last          0.843930
#                         neuralmind/bert-large-portuguese-cased             0.835841
#                         neuralmind/bert-base-portuguese-cased              0.830658
#                         eduagarcia-temp/brwac_v1_2__checkpoint_last        0.829477
#                         eduagarcia-temp/brwac_large_v1_2__checkpoint_last  0.828915
# ceia-frases             projetocnj/roberta-base-juridico-v0.3              0.817559
#                         eduagarcia/r_j_v2_checkpoint_12000                 0.816933
#                         eduagarcia-temp/cnj_v1_2__checkpoint_last          0.813967
#                         neuralmind/bert-large-portuguese-cased             0.810187
#                         eduagarcia-temp/brwac_large_v1_2__checkpoint_last  0.797215
#                         neuralmind/bert-base-portuguese-cased              0.796991
#                         eduagarcia-temp/brwac_v1_2__checkpoint_last        0.785330
# UlyssesNER-Br-PL-fine   eduagarcia-temp/brwac_v1_2__checkpoint_last        0.868716
#                         eduagarcia-temp/brwac_large_v1_2__checkpoint_last  0.867607
#                         neuralmind/bert-large-portuguese-cased             0.847388
#                         eduagarcia/r_j_v2_checkpoint_12000                 0.844468
#                         projetocnj/roberta-base-juridico-v0.3              0.838305
#                         neuralmind/bert-base-portuguese-cased              0.838271
#                         eduagarcia-temp/cnj_v1_2__checkpoint_last          0.832238
# UlyssesNER-Br-PL-coarse eduagarcia-temp/brwac_large_v1_2__checkpoint_last  0.893515
#                         eduagarcia-temp/brwac_v1_2__checkpoint_last        0.884588
#                         neuralmind/bert-large-portuguese-cased             0.877673
#                         eduagarcia/r_j_v2_checkpoint_12000                 0.870165
#                         neuralmind/bert-base-portuguese-cased              0.863900
#                         eduagarcia-temp/cnj_v1_2__checkpoint_last          0.850405
#                         projetocnj/roberta-base-juridico-v0.3              0.839119
# UlyssesNER-Br-C-fine    eduagarcia-temp/brwac_large_v1_2__checkpoint_last  0.774630
#                         neuralmind/bert-large-portuguese-cased             0.765159
#                         eduagarcia/r_j_v2_checkpoint_12000                 0.734465
#                         neuralmind/bert-base-portuguese-cased              0.720454
#                         eduagarcia-temp/brwac_v1_2__checkpoint_last        0.719074
#                         eduagarcia-temp/cnj_v1_2__checkpoint_last          0.704332
#                         projetocnj/roberta-base-juridico-v0.3              0.695546
# UlyssesNER-Br-C-coarse  eduagarcia-temp/brwac_large_v1_2__checkpoint_last  0.777800
#                         neuralmind/bert-base-portuguese-cased              0.759515
#                         neuralmind/bert-large-portuguese-cased             0.750276
#                         eduagarcia/r_j_v2_checkpoint_12000                 0.744604
#                         eduagarcia-temp/brwac_v1_2__checkpoint_last        0.732128
#                         projetocnj/roberta-base-juridico-v0.3              0.720830
#                         eduagarcia-temp/cnj_v1_2__checkpoint_last          0.693843
# LeNER-Br                projetocnj/roberta-base-juridico-v0.3              0.912964
#                         eduagarcia/r_j_v2_checkpoint_12000                 0.906193
#                         eduagarcia-temp/cnj_v1_2__checkpoint_last          0.896819
#                         eduagarcia-temp/brwac_large_v1_2__checkpoint_last  0.892277
#                         eduagarcia-temp/brwac_v1_2__checkpoint_last        0.887307
#                         neuralmind/bert-large-portuguese-cased             0.886371
#                         neuralmind/bert-base-portuguese-cased              0.883363

# %%
best_hparams_df.groupby('model_name_or_path')['f1'].mean().sort_values(ascending=False)
# Out:
# model_name_or_path
# eduagarcia-temp/brwac_large_v1_2__checkpoint_last    0.829092
# neuralmind/bert-large-portuguese-cased               0.823740
# eduagarcia/r_j_v2_checkpoint_12000                   0.821570
# neuralmind/bert-base-portuguese-cased                0.816183
# eduagarcia-temp/brwac_v1_2__checkpoint_last          0.813249
# projetocnj/roberta-base-juridico-v0.3                0.796195
# eduagarcia-temp/cnj_v1_2__checkpoint_last            0.783955
# Name: f1, dtype: float64
